# %%
import numpy as np

A = np.array([[4,2],
              [3,1]])

transpose = A.T
det = np.linalg.det(A)

print("Matrix A:")
print(A)

print("Transpose of A:")
print(transpose)

print("Determinant:", round(det,2))
# Out:
# Matrix A:
# [[4 2]
#  [3 1]]
# Transpose of A:
# [[4 3]
#  [2 1]]
# Determinant: -2.0
