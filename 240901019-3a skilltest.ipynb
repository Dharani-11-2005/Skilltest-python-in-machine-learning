# %%
import numpy as np

R = 10
XL = 5j
XC = -2j

Z1 = R + XL + XC
Z_total = 1 / ((1/Z1) + (1/20))

Z_total = complex(round(Z_total.real,2), round(Z_total.imag,2))
print("Series Impedance:", Z1)
print("Total Impedance:", Z_total)
# Out:
# Series Impedance: (10+3j)
# Total Impedance: (6.8+1.32j)
